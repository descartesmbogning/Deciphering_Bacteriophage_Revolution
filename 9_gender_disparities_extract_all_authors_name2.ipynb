# %% [markdown]
# <a href="https://colab.research.google.com/github/descartesmbogning/Deciphering_Bacteriophage_Revolution/blob/main/9_gender_disparities_extract_all_authors_name2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
# %matplotlib inline
import csv

# %%
# Set the figure size - handy for larger output
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [6, 6]
# Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %%
from scipy import stats #the only import you actually need for this
import matplotlib.pyplot as plt
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}

# %%
#example function that tests distribution then picks test accordingly
def test_sig(x, y):
    if stats.shapiro(x).pvalue >= 0.05 and stats.shapiro(y).pvalue >= 0.05: #if they are normally distriuted
        print("t-test")
        return stats.ttest_ind(x,y)
    else:
        print("mann-whitney")
        return stats.mannwhitneyu(x, y)

# %% [markdown]
# # gender disparities

# %%
#Import data
data = pd.read_pickle(f'D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/first_clean/data_scholar_all_year_merge.pkl')[
                                                                                                ['UT (Unique WOS ID)',
                                                                                                'Publication Year',
                                                                                                'Author Full Names', 'Times Cited, All Databases']];
data = data.rename(columns={"UT (Unique WOS ID)": "wos_ID"}).set_index(['wos_ID','Publication Year', 'Times Cited, All Databases'])
data.head()
# Out:
#                                                                                         Author Full Names
# wos_ID              Publication Year Times Cited, All Databases
# wos:a1975ak27200035 1975             106                                       modrich, p; richardson, cc
# wos:a1975bb78600005 1975             28                              esche, h; schweiger, m; trautner, ta
# wos:a1975ak49300025 1975             50                          jazwinski, sm; lindberg, aa; kornberg, a
# wos:a1975al49000001 1975             31                            silberstein, s; inouye, m; studier, fw
# wos:a1975ay53300001 1975             3                                                           levy, jn

# %%
import pandas as pd

# Your DataFrame is named authors_data
authors_list = data['Author Full Names'].str.split(';').explode().str.strip()

# Count the unique author names
unique_authors_count = authors_list.nunique()

print('The number of unique Last authors is:', unique_authors_count)
# Out:
# The number of unique Last authors is: 179375

# %%
authors_list.to_frame()
# Out:
#                                                                 Author Full Names
# wos_ID              Publication Year Times Cited, All Databases
# wos:a1975ak27200035 1975             106                               modrich, p
#                                      106                           richardson, cc
# wos:a1975bb78600005 1975             28                                  esche, h
#                                      28                              schweiger, m
#                                      28                              trautner, ta
# ...                                                                           ...
# wos:001003139700001 2023             0                               subbarao, k.
#                                      0                                 mcgain, f.
# wos:000912073200001 2023             1                                 lee, mieun
#                                      1                               heo, yu been
#                                      1                               woo, han min
#
# [330540 rows x 1 columns]

# %%
from functools import reduce

#
df_expand = data['Author Full Names'].str.split('; ', expand=True)

# extract all the cells data
author_full_names_list = df_expand.stack().explode().droplevel(0).to_frame().reset_index()#.drop('index', axis=1)

###
author_full_names_list_count =author_full_names_list[0].value_counts().to_frame()

## extract firstname
#author_full_names_list_count = author_full_names_list_count.reset_index()
#author_full_names_list_count['firstname'] = author_full_names_list_count['index'].str.split(', ', expand=True)[[1]]

# Save data
author_full_names_list_count.to_pickle(f'D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/table/author_full_names_list_count.pkl')
author_full_names_list_count.to_csv(f'D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/table/author_full_names_list_count.csv')

#print
author_full_names_list_count
# Out:
#                          0
# salas, m               201
# lavigne, rob           161
# bamford, dh            160
# hatfull, graham f.     144
# moineau, sylvain       142
# ...                    ...
# bullard, rebecca s.      1
# czymmek, kirk            1
# evans, angelo            1
# van golen, kenneth l.    1
# woo, han min             1
#
# [179375 rows x 1 columns]

# %% [markdown]
# # Import data with gender infos

# %%
# Import data with gender infos
all_author_full_names_list = pd.read_excel('D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/table/author-full-names-list-count-openrefine-csv_bon.xlsx')
#all_author_full_names_list = all_author_full_names_list.set_index('firstname')
all_author_full_names_list = all_author_full_names_list.applymap(lambda s:s.lower() if type(s) == str else s)#.set_index(['wos_ID','Publication Year'])
all_author_full_names_list['firstname'] = all_author_full_names_list['firstname'].astype('str')
all_author_full_names_list#.head()
# Out:
#   all_name_clean      all_name firstname
# 0   pluckthun, a  pluckthun, a         a
# 1   toussaint, a  toussaint, a         a
# 2       landy, a      landy, a         a
# 3      taketo, a     taketo, a         a
# 4     wegrzyn, a    wegrzyn, a         a

# %%
# Import data with gender infos
all_author_first_names_list_and_gender = pd.read_excel('D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/table/first_name_genderize.xlsx')
#all_author_first_names_list_and_gender = all_author_first_names_list_and_gender.set_index('firstname')
all_author_first_names_list_and_gender = all_author_first_names_list_and_gender.applymap(lambda s:s.lower() if type(s) == str else s)#.set_index(['wos_ID','Publication Year'])
all_author_first_names_list_and_gender['firstname'] = all_author_first_names_list_and_gender['firstname'].astype('str')
all_author_first_names_list_and_gender#.head()
# Out:
#    firstname ga_first_name ga_last_name ga_gender  ga_accuracy  ga_samples
# 0          a           NaN          NaN       NaN          NaN         NaN
# 1         a            NaN          NaN       NaN          NaN         NaN
# 2       a a            NaN          NaN       NaN          NaN         NaN
# 3     a a s          a a s        a a s      male        100.0         2.0
# 4   a allart        allart            a      male         57.0        23.0

# %%
# You can merge df1 and df2 on the 'key' column like this:
all_author_full_names_list_concat =  all_author_full_names_list.merge( all_author_first_names_list_and_gender, on='firstname', how='left')
all_author_full_names_list_concat.head(60)
# Out:
#              all_name_clean                 all_name firstname ga_first_name  \
# 0              pluckthun, a             pluckthun, a         a           NaN
# 1              toussaint, a             toussaint, a         a           NaN
# 2                  landy, a                 landy, a         a           NaN
# 3                 taketo, a                taketo, a         a           NaN
# 4                wegrzyn, a               wegrzyn, a         a           NaN
# 5                shimizu, a               shimizu, a         a           NaN
# 6                 becker, a                becker, a         a           NaN
# 7               bradbury, a              bradbury, a         a           NaN
# 8                 fekete, a                fekete, a         a           NaN
# 9             hochschild, a            hochschild, a         a           NaN
# 10               nicosia, a               nicosia, a         a           NaN
# 11                   das, a                   das, a         a           NaN
# 12                coffey, a                coffey, a         a           NaN
# 13                  kuhn, a                  kuhn, a         a           NaN
# 14                  bock, a                  bock, a         a           NaN
# 15              holmgren, a              holmgren, a         a           NaN
# 16               charbit, a               charbit, a         a           NaN
# 17              campbell, a              campbell, a         a           NaN
# 18               bruttin, a               bruttin, a         a           NaN
# 19              kornberg, a              kornberg, a         a           NaN
# 20                 bravo, a                 bravo, a         a           NaN
# 21              honegger, a              honegger, a         a           NaN
# 22            villaverde, a            villaverde, a         a           NaN
# 23              goldfarb, a              goldfarb, a         a           NaN
# 24             quiberoni, a             quiberoni, a         a           NaN
# 25                 witte, a                 witte, a         a           NaN
# 26              ishihama, a              ishihama, a         a           NaN
# 27               luzzago, a               luzzago, a         a           NaN
# 28                 engel, a                 engel, a         a           NaN
# 29              audurier, a              audurier, a         a           NaN
# 30               tsugita, a               tsugita, a         a           NaN
# 31               camacho, a               camacho, a         a           NaN
# 32                taylor, a                taylor, a         a           NaN
# 33                martin, a                martin, a         a           NaN
# 34           piekarowicz, a           piekarowicz, a         a           NaN
# 35              cattaneo, a              cattaneo, a         a           NaN
# 36  kucharewiczkrukowska, a  kucharewiczkrukowska, a         a           NaN
# 37              buckling, a             buckling, a.         a           NaN
# 38                 ghosh, a                 ghosh, a         a           NaN
# 39                schots, a                schots, a         a           NaN
# 40                murata, a                murata, a         a           NaN
# 41                bernad, a                bernad, a         a           NaN
# 42                berces, a                berces, a         a           NaN
# 43                tomasz, a                tomasz, a         a           NaN
# 44                  klug, a                  klug, a         a           NaN
# 45                vindel, a                vindel, a         a           NaN
# 46            cloeckaert, a            cloeckaert, a         a           NaN
# 47                tanaka, a                tanaka, a         a           NaN
# 48            tramontano, a            tramontano, a         a           NaN
# 49                engert, a                engert, a         a           NaN
# 50                 klein, a                 klein, a         a           NaN
# 51              siitonen, a              siitonen, a         a           NaN
# 52    herman-antosiewicz, a    herman-antosiewicz, a         a           NaN
# 53                godany, a                godany, a         a           NaN
# 54            simoncsits, a            simoncsits, a         a           NaN
# 55                 kumar, a                 kumar, a         a           NaN
# 56                skerra, a                skerra, a         a           NaN
# 57                nissim, a                nissim, a         a           NaN
# 58               nastasi, a               nastasi, a         a           NaN
# 59                  wada, a                  wada, a         a           NaN
#
#    ga_last_name ga_gender  ga_accuracy  ga_samples
# 0           NaN       NaN          NaN         NaN
# 1           NaN       NaN          NaN         NaN
# 2           NaN       NaN          NaN         NaN
# 3           NaN       NaN          NaN         NaN
# 4           NaN       NaN          NaN         NaN
# 5           NaN       NaN          NaN         NaN
# 6           NaN       NaN          NaN         NaN
# 7           NaN       NaN          NaN         NaN
# 8           NaN       NaN          NaN         NaN
# 9           NaN       NaN          NaN         NaN
# 10          NaN       NaN          NaN         NaN
# 11          NaN       NaN          NaN         NaN
# 12          NaN       NaN          NaN         NaN
# 13          NaN       NaN          NaN         NaN
# 14          NaN       NaN          NaN         NaN
# 15          NaN       NaN          NaN         NaN
# 16          NaN       NaN          NaN         NaN
# 17          NaN       NaN          NaN         NaN
# 18          NaN       NaN          NaN         NaN
# 19          NaN       NaN          NaN         NaN
# 20          NaN       NaN          NaN         NaN
# 21          NaN       NaN          NaN         NaN
# 22          NaN       NaN          NaN         NaN
# 23          NaN       NaN          NaN         NaN
# 24          NaN       NaN          NaN         NaN
# 25          NaN       NaN          NaN         NaN
# 26          NaN       NaN          NaN         NaN
# 27          NaN       NaN          NaN         NaN
# 28          NaN       NaN          NaN         NaN
# 29          NaN       NaN          NaN         NaN
# 30          NaN       NaN          NaN         NaN
# 31          NaN       NaN          NaN         NaN
# 32          NaN       NaN          NaN         NaN
# 33          NaN       NaN          NaN         NaN
# 34          NaN       NaN          NaN         NaN
# 35          NaN       NaN          NaN         NaN
# 36          NaN       NaN          NaN         NaN
# 37          NaN       NaN          NaN         NaN
# 38          NaN       NaN          NaN         NaN
# 39          NaN       NaN          NaN         NaN
# 40          NaN       NaN          NaN         NaN
# 41          NaN       NaN          NaN         NaN
# 42          NaN       NaN          NaN         NaN
# 43          NaN       NaN          NaN         NaN
# 44          NaN       NaN          NaN         NaN
# 45          NaN       NaN          NaN         NaN
# 46          NaN       NaN          NaN         NaN
# 47          NaN       NaN          NaN         NaN
# 48          NaN       NaN          NaN         NaN
# 49          NaN       NaN          NaN         NaN
# 50          NaN       NaN          NaN         NaN
# 51          NaN       NaN          NaN         NaN
# 52          NaN       NaN          NaN         NaN
# 53          NaN       NaN          NaN         NaN
# 54          NaN       NaN          NaN         NaN
# 55          NaN       NaN          NaN         NaN
# 56          NaN       NaN          NaN         NaN
# 57          NaN       NaN          NaN         NaN
# 58          NaN       NaN          NaN         NaN
# 59          NaN       NaN          NaN         NaN

# %%
authors_list
# Out:
# wos_ID               Publication Year  Times Cited, All Databases
# wos:a1975ak27200035  1975              106                               modrich, p
#                                        106                           richardson, cc
# wos:a1975bb78600005  1975              28                                  esche, h
#                                        28                              schweiger, m
#                                        28                              trautner, ta
#                                                                           ...
# wos:001003139700001  2023              0                               subbarao, k.
#                                        0                                 mcgain, f.
# wos:000912073200001  2023              1                                 lee, mieun
#                                        1                               heo, yu been
#                                        1                               woo, han min
# Name: Author Full Names, Length: 330540, dtype: object

# %%
# You can merge df1 and df2 on the 'key' column like this:
all_author_full_names_list_concat_ID =  authors_list.to_frame().reset_index().merge(all_author_full_names_list_concat, left_on='Author Full Names' , right_on='all_name' , how='left')
all_author_full_names_list_concat_ID_gender = all_author_full_names_list_concat_ID.set_index(['wos_ID', 'Publication Year'])
all_author_full_names_list_concat_ID_gender = all_author_full_names_list_concat_ID_gender[['ga_gender']]
all_author_full_names_list_concat_ID_gender['ga_gender'] = all_author_full_names_list_concat_ID_gender['ga_gender'].fillna("unclassified")

all_author_full_names_list_concat_ID_gender
# Out:
#                                          ga_gender
# wos_ID              Publication Year
# wos:a1975ak27200035 1975              unclassified
#                     1975                      male
# wos:a1975bb78600005 1975                      male
#                     1975              unclassified
#                     1975                      male
# ...                                            ...
# wos:001003139700001 2023              unclassified
#                     2023              unclassified
# wos:000912073200001 2023                    female
#                     2023                      male
#                     2023                      male
#
# [330540 rows x 1 columns]

# %%
all_author_full_names_list_concat_ID.columns
# Out:
# Index(['wos_ID', 'Publication Year', 'Times Cited, All Databases',
#        'Author Full Names', 'all_name_clean', 'all_name', 'firstname',
#        'ga_first_name', 'ga_last_name', 'ga_gender', 'ga_accuracy',
#        'ga_samples'],
#       dtype='object')

# %%
from functools import reduce

## get dummies to have contries on columns
dfs = [pd.get_dummies(all_author_full_names_list_concat_ID_gender[col]) for col in ['ga_gender']]
d = reduce(lambda x,y : x.add(y, fill_value=0), dfs)

# data cleaning
cols = [c for c in d.columns if c[-1:] != '.']
df=d[cols]
cols = [c for c in df.columns.to_list() if len(c) != 1]
data_author_lower_dummies=df[cols]
data_author_lower_dummies
# Out:
#                                       female  male  unclassified  unknown
# wos_ID              Publication Year
# wos:a1975ak27200035 1975                   0     0             1        0
#                     1975                   0     1             0        0
# wos:a1975bb78600005 1975                   0     1             0        0
#                     1975                   0     0             1        0
#                     1975                   0     1             0        0
# ...                                      ...   ...           ...      ...
# wos:001003139700001 2023                   0     0             1        0
#                     2023                   0     0             1        0
# wos:000912073200001 2023                   1     0             0        0
#                     2023                   0     1             0        0
#                     2023                   0     1             0        0
#
# [330540 rows x 4 columns]

# %%
# and sum citations within each group
data_author_lower_dummies = data_author_lower_dummies.reset_index().groupby(['wos_ID','Publication Year']).sum()
data_author_lower_dummies#.tail(60)
# Out:
#                                       female  male  unclassified  unknown  \
# wos_ID              Publication Year
# wos:000070986500004 1997                   0     4             3        0
# wos:000070998700002 1997                   0     2             5        0
# wos:000070998700004 1997                   0     3             0        0
# wos:000070998700009 1997                   0     1             2        0
# wos:000071002800012 1997                   0     1             1        0
# ...                                      ...   ...           ...      ...
# wos:a1997yl41900069 1997                   0     3             1        0
# wos:a1997yl41900095 1997                   0     5             3        0
# wos:a1997yl54300005 1997                   0     6             2        0
# wos:a1998yl01000069 1998                   0     4             4        0
# wos:a1998yl01000085 1998                   0     6             2        0
#
#                                       number_of_author  %_female    %_male  \
# wos_ID              Publication Year
# wos:000070986500004 1997                    721.980392       0.0  0.554032
# wos:000070998700002 1997                    721.980392       0.0  0.277016
# wos:000070998700004 1997                    309.980392       0.0  0.967803
# wos:000070998700009 1997                    309.980392       0.0  0.322601
# wos:000071002800012 1997                    206.980392       0.0  0.483138
# ...                                                ...       ...       ...
# wos:a1997yl41900069 1997                    412.980392       0.0  0.726427
# wos:a1997yl41900095 1997                    824.980392       0.0  0.606075
# wos:a1997yl54300005 1997                    824.980392       0.0  0.727290
# wos:a1998yl01000069 1998                    824.980392       0.0  0.484860
# wos:a1998yl01000085 1998                    824.980392       0.0  0.727290
#
#                                       %_unclass_name  female_to_male_ratio
# wos_ID              Publication Year
# wos:000070986500004 1997                    0.415524                   0.0
# wos:000070998700002 1997                    0.692540                   0.0
# wos:000070998700004 1997                    0.000000                   0.0
# wos:000070998700009 1997                    0.645202                   0.0
# wos:000071002800012 1997                    0.483138                   0.0
# ...                                              ...                   ...
# wos:a1997yl41900069 1997                    0.242142                   0.0
# wos:a1997yl41900095 1997                    0.363645                   0.0
# wos:a1997yl54300005 1997                    0.242430                   0.0
# wos:a1998yl01000069 1998                    0.484860                   0.0
# wos:a1998yl01000085 1998                    0.242430                   0.0
#
# [61544 rows x 9 columns]

# %%
data_author_lower_dummies['number_of_author'] = data_author_lower_dummies.sum(axis='columns')
data_author_lower_dummies['%_female'] = data_author_lower_dummies['female']/data_author_lower_dummies['number_of_author']*100
data_author_lower_dummies['%_male'] = data_author_lower_dummies['male']/data_author_lower_dummies['number_of_author']*100
# data_author_lower['number_of_unknown_or_unclassified'] = ((data_author_lower == '/') | (data_author_lower == 'unknown')).sum(axis=1)
data_author_lower_dummies['%_unclass_name'] = data_author_lower_dummies['unclassified']/data_author_lower_dummies['number_of_author']*100
data_author_lower_dummies['female_to_male_ratio'] = data_author_lower_dummies['female']/data_author_lower_dummies['male']
# data_author_lower['first_author_gender'] = data_author_lower[0]
# data_author_lower['first_author_gender'] =

#save data
data_author_lower_dummies.to_csv(f'D:\PROJECT/YORK UNIVERSITY/BACTERIOPHAGES/data_analyse/global_south/table/author_gender_list_count_dummies.csv')

data_author_lower_dummies
# Out:
#                                       female  male  unclassified  unknown  \
# wos_ID              Publication Year
# wos:000070986500004 1997                   0     4             3        0
# wos:000070998700002 1997                   0     2             5        0
# wos:000070998700004 1997                   0     3             0        0
# wos:000070998700009 1997                   0     1             2        0
# wos:000071002800012 1997                   0     1             1        0
# ...                                      ...   ...           ...      ...
# wos:a1997yl41900069 1997                   0     3             1        0
# wos:a1997yl41900095 1997                   0     5             3        0
# wos:a1997yl54300005 1997                   0     6             2        0
# wos:a1998yl01000069 1998                   0     4             4        0
# wos:a1998yl01000085 1998                   0     6             2        0
#
#                                       number_of_author  %_female    %_male  \
# wos_ID              Publication Year
# wos:000070986500004 1997                    721.980392       0.0  0.554032
# wos:000070998700002 1997                    721.980392       0.0  0.277016
# wos:000070998700004 1997                    309.980392       0.0  0.967803
# wos:000070998700009 1997                    309.980392       0.0  0.322601
# wos:000071002800012 1997                    206.980392       0.0  0.483138
# ...                                                ...       ...       ...
# wos:a1997yl41900069 1997                    412.980392       0.0  0.726427
# wos:a1997yl41900095 1997                    824.980392       0.0  0.606075
# wos:a1997yl54300005 1997                    824.980392       0.0  0.727290
# wos:a1998yl01000069 1998                    824.980392       0.0  0.484860
# wos:a1998yl01000085 1998                    824.980392       0.0  0.727290
#
#                                       %_unclass_name  female_to_male_ratio
# wos_ID              Publication Year
# wos:000070986500004 1997                    0.415524                   0.0
# wos:000070998700002 1997                    0.692540                   0.0
# wos:000070998700004 1997                    0.000000                   0.0
# wos:000070998700009 1997                    0.645202                   0.0
# wos:000071002800012 1997                    0.483138                   0.0
# ...                                              ...                   ...
# wos:a1997yl41900069 1997                    0.242142                   0.0
# wos:a1997yl41900095 1997                    0.363645                   0.0
# wos:a1997yl54300005 1997                    0.242430                   0.0
# wos:a1998yl01000069 1998                    0.484860                   0.0
# wos:a1998yl01000085 1998                    0.242430                   0.0
#
# [61544 rows x 9 columns]

# %%
data_author_lower_dummies.describe()
# Out:
#              female          male  unclassified       unknown  \
# count  61544.000000  61544.000000  61544.000000  61544.000000
# mean       1.196997      3.078350      1.079098      0.016346
# std        2.046713      2.641723      1.768241      0.133300
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      0.000000
# 50%        0.000000      3.000000      0.000000      0.000000
# 75%        2.000000      4.000000      2.000000      0.000000
# max      101.000000     87.000000     98.000000      3.000000
#
#        number_of_author      %_female        %_male  %_unclass_name  \
# count      6.154400e+04  61544.000000  61544.000000    61544.000000
# mean                inf      0.153055      0.546849        0.221949
# std                 NaN      0.214864      0.307159        0.316706
# min        1.039804e+02      0.000000      0.000000        0.000000
# 25%        3.099804e+02      0.000000      0.322601        0.000000
# 50%        5.159804e+02      0.000000      0.580667        0.000000
# 75%        7.233137e+02      0.322082      0.775223        0.431044
# max                 inf      0.881424      0.970361        0.970214
#
#        female_to_male_ratio
# count          5.702300e+04
# mean                    inf
# std                     NaN
# min            0.000000e+00
# 25%            0.000000e+00
# 50%            0.000000e+00
# 75%            6.363636e-01
# max                     inf

# %%
# Reset the index to make 'Publication Year' a regular column
data_author_lower_dummies2 = data_author_lower_dummies.reset_index()

# Create a new column, 'Year Group', to indicate which 5-year group each row belongs to
data_author_lower_dummies2['Year Group'] = pd.cut(data_author_lower_dummies2['Publication Year'], bins=range(1973, 2024, 5), right=True)

# Drop unnecessary columns
data_author_lower_dummies2.drop(['wos_ID', 'Publication Year'], axis=1, inplace=True)
data_author_lower_dummies2
# Out:
#        female  male  unclassified  unknown  number_of_author  %_female  \
# 0           0     4             3        0        721.980392       0.0
# 1           0     2             5        0        721.980392       0.0
# 2           0     3             0        0        309.980392       0.0
# 3           0     1             2        0        309.980392       0.0
# 4           0     1             1        0        206.980392       0.0
# ...       ...   ...           ...      ...               ...       ...
# 61539       0     3             1        0        412.980392       0.0
# 61540       0     5             3        0        824.980392       0.0
# 61541       0     6             2        0        824.980392       0.0
# 61542       0     4             4        0        824.980392       0.0
# 61543       0     6             2        0        824.980392       0.0
#
#          %_male  %_unclass_name  female_to_male_ratio    Year Group
# 0      0.554032        0.415524                   0.0  (1993, 1998]
# 1      0.277016        0.692540                   0.0  (1993, 1998]
# 2      0.967803        0.000000                   0.0  (1993, 1998]
# 3      0.322601        0.645202                   0.0  (1993, 1998]
# 4      0.483138        0.483138                   0.0  (1993, 1998]
# ...         ...             ...                   ...           ...
# 61539  0.726427        0.242142                   0.0  (1993, 1998]
# 61540  0.606075        0.363645                   0.0  (1993, 1998]
# 61541  0.727290        0.242430                   0.0  (1993, 1998]
# 61542  0.484860        0.484860                   0.0  (1993, 1998]
# 61543  0.727290        0.242430                   0.0  (1993, 1998]
#
# [61544 rows x 10 columns]

# %%
# and sum citations within each group
data_author_lower_dummies2 = data_author_lower_dummies2.reset_index().groupby(['Year Group']).mean().drop(columns='index')
data_author_lower_dummies2#.tail(60)
# Out:
#                 female      male  unclassified   unknown  number_of_author  \
# Year Group
# (1973, 1978]  0.087617  1.465355      1.158248  0.000000               NaN
# (1978, 1983]  0.080537  1.601510      1.224832  0.001258               NaN
# (1983, 1988]  0.082253  1.774676      1.283151  0.000499               NaN
# (1988, 1993]  0.097885  1.979289      1.509701  0.000872               NaN
# (1993, 1998]  0.086809  2.150355      1.844113  0.001560               NaN
# (1998, 2003]  0.107229  2.391280      2.223122  0.000852               NaN
# (2003, 2008]  0.877136  3.067399      1.407648  0.008408               NaN
# (2008, 2013]  1.793207  3.688913      0.493601  0.021170               NaN
# (2013, 2018]  2.119958  3.944456      0.421753  0.029567               NaN
# (2018, 2023]  2.697299  4.251042      0.384901  0.041871               NaN
#
#               %_female    %_male  %_unclass_name  female_to_male_ratio
# Year Group
# (1973, 1978]  0.013891  0.524252        0.394717                   NaN
# (1978, 1983]  0.013804  0.536170        0.391706                   NaN
# (1983, 1988]  0.013324  0.554019        0.372324                   NaN
# (1988, 1993]  0.015038  0.544737        0.376072                   NaN
# (1993, 1998]  0.013078  0.526432        0.401384                   NaN
# (1998, 2003]  0.014540  0.500564        0.423885                   NaN
# (2003, 2008]  0.129490  0.544804        0.246984                   NaN
# (2008, 2013]  0.248070  0.585134        0.077521                   NaN
# (2013, 2018]  0.273518  0.575792        0.060069                   NaN
# (2018, 2023]  0.312320  0.543408        0.046973                   NaN

# %%
# Last, let's reshape the DataFrame so each row is a country-publication pair
melted_df = pd.melt(wb_region_group_data2, id_vars=['Year Group', 'Times Cited, All Databases'], var_name='wb_region', value_name='Publication')

# Now, we can drop the rows where 'Publication' is NaN (indicating no publication for that country)
melted_df.dropna(subset=['Publication'], inplace=True)

# Now we'll group by 'Year Group' and 'Country', and calculate the count of 'Publication' and the sum of 'Times Cited, All Databases'
grouped = melted_df.groupby(['Year Group', 'wb_region']).agg({'Publication': 'count', 'Times Cited, All Databases': 'sum'}).reset_index()

# Rename columns
grouped.columns = ['Year Group', 'wb_region', 'Publication Count',	'Total Citation']


grouped

# %% [markdown]
# ## ALL

# %%
from functools import reduce

#Import data
data = pd.read_excel(f'D:\MARBURG VIRUS DISEASES/data/WOSCC/woscc_bon_23_02_verif_on_wos.xls')[['UT (Unique WOS ID)',
                                                                                                'Publication Year',
                                                                                                'Funding Orgs',
                                                                                                'Author Full Names']];
# limit data to after 2007
data_2007 = data.reset_index()[data.reset_index()['Publication Year'] > 2006]
data_2007.head()

# create a columns of funding yes or no
data_2007['funding_yes'] = data_2007['Funding Orgs'].apply(lambda x: 1 if not pd.isnull(x) else 0)#.to_frame().drop('Funding Orgs', axis=1)

# set accession number as index
data_2007 = data_2007.set_index(['UT (Unique WOS ID)','Publication Year','Funding Orgs','funding_yes'])

#
df_expand_2007 = data_2007['Author Full Names'].str.split('; ', expand=True)

# extract all the cells data
author_full_names_list_2007 = df_expand_2007.stack().explode().droplevel(0).to_frame().reset_index()#.drop('index', axis=1)

###
author_full_names_list_count_2007 =author_full_names_list_2007[0].value_counts().to_frame()

## extract firstname
# author_full_names_list_count_2007 = author_full_names_list_count_2007.reset_index()
# author_full_names_list_count_2007['firstname'] = author_full_names_list_count_2007['index'].str.split(', ', expand=True)[[1]]

 #save data
author_full_names_list_count_2007.to_csv(f'../DATA_PREPROCESSING/author_full_names_list_count_and_firstname_2007.csv')

#print
author_full_names_list_count_2007
# Out:
#                            0
# Bavari, Sina              52
# Geisbert, Thomas W.       46
# Feldmann, Heinz           42
# Becker, Stephan           32
# Basler, Christopher F.    31
# ...                       ..
# Cheptoyek, Leonard         1
# Wangila, Barasa Emmanuel   1
# Wanje, Michael             1
# Tusiime, Patrick           1
# Grant, Alison D.           1
#
# [3593 rows x 1 columns]

# %%
author_full_names_list_count_2007 = author_full_names_list_count_2007.reset_index().rename(columns={0:'number_publication'})
author_full_names_list_count_2007['full_name'] = author_full_names_list_count_2007['index'].str.lower()
author_full_names_list_count_2007
# Out:
#                          index  number_publication                 full_name
# 0                 Bavari, Sina                  52              bavari, sina
# 1          Geisbert, Thomas W.                  46       geisbert, thomas w.
# 2              Feldmann, Heinz                  42           feldmann, heinz
# 3              Becker, Stephan                  32           becker, stephan
# 4       Basler, Christopher F.                  31    basler, christopher f.
# ...                        ...                 ...                       ...
# 3588        Cheptoyek, Leonard                   1        cheptoyek, leonard
# 3589  Wangila, Barasa Emmanuel                   1  wangila, barasa emmanuel
# 3590            Wanje, Michael                   1            wanje, michael
# 3591          Tusiime, Patrick                   1          tusiime, patrick
# 3592          Grant, Alison D.                   1          grant, alison d.
#
# [3593 rows x 3 columns]

# %%
all_author_full_names_gender_2007_concat = author_full_names_list_count_2007.merge(all_author_full_names_list_and_gender, on = 'full_name', how='left')
all_author_full_names_gender_2007_concat
# Out:
#                          index  number_publication                 full_name  \
# 0                 Bavari, Sina                  52              bavari, sina
# 1          Geisbert, Thomas W.                  46       geisbert, thomas w.
# 2              Feldmann, Heinz                  42           feldmann, heinz
# 3              Becker, Stephan                  32           becker, stephan
# 4       Basler, Christopher F.                  31    basler, christopher f.
# ...                        ...                 ...                       ...
# 3596        Cheptoyek, Leonard                   1        cheptoyek, leonard
# 3597  Wangila, Barasa Emmanuel                   1  wangila, barasa emmanuel
# 3598            Wanje, Michael                   1            wanje, michael
# 3599          Tusiime, Patrick                   1          tusiime, patrick
# 3600          Grant, Alison D.                   1          grant, alison d.
#
#       Unnamed: 0   0        firstname    ga_first_name ga_gender  ga_accuracy  \
# 0              0  54             Sina             Sina      male         63.0
# 1              1  47        Thomas W.        Thomas W.      male        100.0
# 2              2  44            Heinz            Heinz      male         98.0
# 3              4  32          Stephan          Stephan      male         99.0
# 4              6  31   Christopher F.      Christopher      male         99.0
# ...          ...  ..              ...              ...       ...          ...
# 3596        3754   1          Leonard          Leonard      male         98.0
# 3597        3755   1  Barasa Emmanuel  Barasa Emmanuel      male         99.0
# 3598        3756   1          Michael          Michael      male         99.0
# 3599        3757   1          Patrick          Patrick      male         99.0
# 3600        1887   1        Alison D.        Alison D.    female        100.0
#
#       ga_samples Unnamed: 8
# 0         5878.0          0
# 1           24.0          0
# 2         3977.0          0
# 3        19941.0          0
# 4        55041.0          0
# ...          ...        ...
# 3596      7077.0          0
# 3597     43698.0          0
# 3598    211741.0          0
# 3599    118290.0          0
# 3600         2.0          0
#
# [3601 rows x 11 columns]

# %%
all_author_full_names_gender_2007_concat['ga_gender'].value_counts()
# Out:
# male            2139
# female          1303
# unclassified     141
# unknown           18
# Name: ga_gender, dtype: int64

# %%
all_author_full_names_gender_2007_concat['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.594002
# female          0.361844
# unclassified    0.039156
# unknown         0.004999
# Name: ga_gender, dtype: float64

# %%
# year_gender = data_author_lower_dummies.reset_index()[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']
#                                                      ].groupby(['Publication Year']).agg({'female': 'sum', 'male': 'sum',
#                                                                                           'unclassified': 'sum', 'unknown': 'sum', 'number_of_author': 'sum',
#                                                                                           'UT (Unique WOS ID)': 'count'})

# year_gender['female_to_male_ratio'] = year_gender['female']/year_gender['male']
# year_gender['publication_to_authors_number_ratio'] = year_gender['number_of_author']/year_gender['UT (Unique WOS ID)']

# for col in ['female','male','unclassified','unknown']:
#     year_gender['%_'+col] = year_gender[col]/year_gender['number_of_author']*100

# # #save data
# year_gender.to_csv(f'../TABLES/year_gender_count.csv')
# year_gender

# %%
# year_gender = data_author_lower_dummies[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']].groupby(['Publication Year']).sum()#.drop('funding_yes',axis=1)
# year_gender['female_to_male_ratio'] = year_gender['female']/year_gender['male']

# for col in ['female','male','unclassified','unknown']:
#     year_gender['%_'+col] = year_gender[col]/year_gender['number_of_author']*100

# # #save data
# year_gender.to_csv(f'../DATA_PREPROCESSING/year_gender_count.csv')
# year_gender

# %%
# fund_data_author_lower_dummies

# %% [markdown]
# ## funding

# %%
from functools import reduce

#Import data
data = pd.read_excel(f'D:\MARBURG VIRUS DISEASES/data/WOSCC/woscc_bon_23_02_verif_on_wos.xls')[['UT (Unique WOS ID)',
                                                                                                'Publication Year',
                                                                                                'Funding Orgs',
                                                                                                'Author Full Names']];
# limit data to after 2007
data_2007 = data.reset_index()[data.reset_index()['Publication Year'] > 2006]
data_2007.head()

# create a columns of funding yes or no
data_2007['funding_yes'] = data_2007['Funding Orgs'].apply(lambda x: 1 if not pd.isnull(x) else 0)#.to_frame().drop('Funding Orgs', axis=1)

data_2007 = data_2007.reset_index().loc[data_2007.reset_index()['funding_yes'] == 1]

# set accession number as index
data_2007 = data_2007.set_index(['UT (Unique WOS ID)','Publication Year','Funding Orgs','funding_yes'])

#
df_expand_2007 = data_2007['Author Full Names'].str.split('; ', expand=True)

# extract all the cells data
author_full_names_list_2007 = df_expand_2007.stack().explode().droplevel(0).to_frame().reset_index()#.drop('index', axis=1)

###
fund_author_full_names_list_count_2007 =author_full_names_list_2007[0].value_counts().to_frame()

## extract firstname
# author_full_names_list_count_2007 = author_full_names_list_count_2007.reset_index()
# author_full_names_list_count_2007['firstname'] = author_full_names_list_count_2007['index'].str.split(', ', expand=True)[[1]]

 #save data
fund_author_full_names_list_count_2007.to_csv(f'../DATA_PREPROCESSING/author_full_names_list_count_and_firstname_2007_fund.csv')

#print
fund_author_full_names_list_count_2007
# Out:
#                          0
# Bavari, Sina            46
# Geisbert, Thomas W.     40
# Feldmann, Heinz         34
# Basler, Christopher F.  31
# Becker, Stephan         26
# ...                     ..
# Kwesiga, Benon           1
# Kofman, Aaron            1
# Masiira, Ben             1
# Brown, Shelley           1
# Lipkin, W. Ian           1
#
# [3144 rows x 1 columns]

# %%
fund_author_full_names_list_count_2007 = fund_author_full_names_list_count_2007.reset_index().rename(columns={0:'number_publication'})
fund_author_full_names_list_count_2007['full_name'] = fund_author_full_names_list_count_2007['index'].str.lower()
fund_author_full_names_list_count_2007
# Out:
#                        index  number_publication               full_name
# 0               Bavari, Sina                  46            bavari, sina
# 1        Geisbert, Thomas W.                  40     geisbert, thomas w.
# 2            Feldmann, Heinz                  34         feldmann, heinz
# 3     Basler, Christopher F.                  31  basler, christopher f.
# 4            Becker, Stephan                  26         becker, stephan
# ...                      ...                 ...                     ...
# 3139          Kwesiga, Benon                   1          kwesiga, benon
# 3140           Kofman, Aaron                   1           kofman, aaron
# 3141            Masiira, Ben                   1            masiira, ben
# 3142          Brown, Shelley                   1          brown, shelley
# 3143          Lipkin, W. Ian                   1          lipkin, w. ian
#
# [3144 rows x 3 columns]

# %%
fund_author_full_names_list_count_2007_concat = fund_author_full_names_list_count_2007.merge(all_author_full_names_list_and_gender, on = 'full_name', how='left')
fund_author_full_names_list_count_2007_concat
# Out:
#                        index  number_publication               full_name  \
# 0               Bavari, Sina                  46            bavari, sina
# 1        Geisbert, Thomas W.                  40     geisbert, thomas w.
# 2            Feldmann, Heinz                  34         feldmann, heinz
# 3     Basler, Christopher F.                  31  basler, christopher f.
# 4            Becker, Stephan                  26         becker, stephan
# ...                      ...                 ...                     ...
# 3146          Kwesiga, Benon                   1          kwesiga, benon
# 3147           Kofman, Aaron                   1           kofman, aaron
# 3148            Masiira, Ben                   1            masiira, ben
# 3149          Brown, Shelley                   1          brown, shelley
# 3150          Lipkin, W. Ian                   1          lipkin, w. ian
#
#       Unnamed: 0   0       firstname ga_first_name ga_gender  ga_accuracy  \
# 0              0  54            Sina          Sina      male         63.0
# 1              1  47       Thomas W.     Thomas W.      male        100.0
# 2              2  44           Heinz         Heinz      male         98.0
# 3              6  31  Christopher F.   Christopher      male         99.0
# 4              4  32         Stephan       Stephan      male         99.0
# ...          ...  ..             ...           ...       ...          ...
# 3146        3794   1           Benon         Benon      male         99.0
# 3147        3795   1           Aaron         Aaron      male         99.0
# 3148        3796   1             Ben           Ben      male         97.0
# 3149        3797   1         Shelley       Shelley    female         98.0
# 3150         336   3          W. Ian        W. Ian      male        100.0
#
#       ga_samples Unnamed: 8
# 0         5878.0          0
# 1           24.0          0
# 2         3977.0          0
# 3        55041.0          0
# 4        19941.0          0
# ...          ...        ...
# 3146        91.0          0
# 3147     36714.0          0
# 3148     73526.0          0
# 3149      4087.0          0
# 3150         3.0          0
#
# [3151 rows x 11 columns]

# %%
fund_author_full_names_list_count_2007_concat['ga_gender'].value_counts()
# Out:
# male            1861
# female          1158
# unclassified     115
# unknown           17
# Name: ga_gender, dtype: int64

# %%
fund_author_full_names_list_count_2007_concat['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.590606
# female          0.367502
# unclassified    0.036496
# unknown         0.005395
# Name: ga_gender, dtype: float64

# %%
# fund_data_author_lower_dummies = data_author_lower_dummies.reset_index().loc[data_author_lower_dummies.reset_index()['funding_yes'] == 1]
# fund_data_author_lower_dummies.shape
# Out:
# (577, 13)

# %%
# fund_year_gender = fund_data_author_lower_dummies.reset_index()[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']
#                                                      ].groupby(['Publication Year']).agg({'female': 'sum', 'male': 'sum',
#                                                                                           'unclassified': 'sum', 'unknown': 'sum', 'number_of_author': 'sum',
#                                                                                           'UT (Unique WOS ID)': 'count'})

# fund_year_gender['female_to_male_ratio'] = fund_year_gender['female']/fund_year_gender['male']
# fund_year_gender['publication_to_authors_number_ratio'] = fund_year_gender['number_of_author']/fund_year_gender['UT (Unique WOS ID)']

# for col in ['female','male','unclassified','unknown']:
#     fund_year_gender['%_'+col] = fund_year_gender[col]/fund_year_gender['number_of_author']*100

# # #save data
# fund_year_gender.to_csv(f'../TABLES/year_gender_fund_count.csv')
# fund_year_gender

# %%
# fund_year_gender = fund_data_author_lower_dummies[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']].groupby(['Publication Year']).sum()#.drop('funding_yes',axis=1)
# fund_year_gender['female_to_male_ratio'] = fund_year_gender['female']/fund_year_gender['male']

# for col in ['female','male','unclassified','unknown']:
#     fund_year_gender['%_'+col] = fund_year_gender[col]/fund_year_gender['number_of_author']*100

# # #save data
# fund_year_gender.to_csv(f'../DATA_PREPROCESSING/year_gender_fund_count.csv')
# fund_year_gender

# %% [markdown]
# ## non funding

# %%
from functools import reduce

#Import data
data = pd.read_excel(f'D:\MARBURG VIRUS DISEASES/data/WOSCC/woscc_bon_23_02_verif_on_wos.xls')[['UT (Unique WOS ID)',
                                                                                                'Publication Year',
                                                                                                'Funding Orgs',
                                                                                                'Author Full Names']];
# limit data to after 2007
data_2007 = data.reset_index()[data.reset_index()['Publication Year'] > 2006]
data_2007.head()

# create a columns of funding yes or no
data_2007['funding_yes'] = data_2007['Funding Orgs'].apply(lambda x: 1 if not pd.isnull(x) else 0)#.to_frame().drop('Funding Orgs', axis=1)

data_2007 = data_2007.reset_index().loc[data_2007.reset_index()['funding_yes'] == 0]

# set accession number as index
data_2007 = data_2007.set_index(['UT (Unique WOS ID)','Publication Year','Funding Orgs','funding_yes'])

#
df_expand_2007 = data_2007['Author Full Names'].str.split('; ', expand=True)

# extract all the cells data
author_full_names_list_2007 = df_expand_2007.stack().explode().droplevel(0).to_frame().reset_index()#.drop('index', axis=1)

###
no_fund_author_full_names_list_count_2007 =author_full_names_list_2007[0].value_counts().to_frame()

## extract firstname
# author_full_names_list_count_2007 = author_full_names_list_count_2007.reset_index()
# author_full_names_list_count_2007['firstname'] = author_full_names_list_count_2007['index'].str.split(', ', expand=True)[[1]]

 #save data
no_fund_author_full_names_list_count_2007.to_csv(f'../DATA_PREPROCESSING/author_full_names_list_count_and_firstname_2007_no_fund.csv')

#print
no_fund_author_full_names_list_count_2007
# Out:
#                         0
# Feldmann, Heinz         8
# Bausch, Daniel G.       6
# Nichol, Stuart T.       6
# Becker, Stephan         6
# Geisbert, Thomas W.     6
# ...                    ..
# Pyankov, Oleg V.        1
# Camara, Jacob           1
# Sylla, Bakary           1
# Agafonov, Alexander P.  1
# Grant, Alison D.        1
#
# [628 rows x 1 columns]

# %%
no_fund_author_full_names_list_count_2007 = no_fund_author_full_names_list_count_2007.reset_index().rename(columns={0:'number_publication'})
no_fund_author_full_names_list_count_2007['full_name'] = no_fund_author_full_names_list_count_2007['index'].str.lower()
no_fund_author_full_names_list_count_2007
# Out:
#                       index  number_publication               full_name
# 0           Feldmann, Heinz                   8         feldmann, heinz
# 1         Bausch, Daniel G.                   6       bausch, daniel g.
# 2         Nichol, Stuart T.                   6       nichol, stuart t.
# 3           Becker, Stephan                   6         becker, stephan
# 4       Geisbert, Thomas W.                   6     geisbert, thomas w.
# ..                      ...                 ...                     ...
# 623        Pyankov, Oleg V.                   1        pyankov, oleg v.
# 624           Camara, Jacob                   1           camara, jacob
# 625           Sylla, Bakary                   1           sylla, bakary
# 626  Agafonov, Alexander P.                   1  agafonov, alexander p.
# 627        Grant, Alison D.                   1        grant, alison d.
#
# [628 rows x 3 columns]

# %%
no_fund_author_full_names_list_count_2007_concat = no_fund_author_full_names_list_count_2007.merge(all_author_full_names_list_and_gender, on = 'full_name', how='left')
no_fund_author_full_names_list_count_2007_concat
# Out:
#                       index  number_publication               full_name  \
# 0           Feldmann, Heinz                   8         feldmann, heinz
# 1         Bausch, Daniel G.                   6       bausch, daniel g.
# 2         Nichol, Stuart T.                   6       nichol, stuart t.
# 3           Becker, Stephan                   6         becker, stephan
# 4       Geisbert, Thomas W.                   6     geisbert, thomas w.
# ..                      ...                 ...                     ...
# 624        Pyankov, Oleg V.                   1        pyankov, oleg v.
# 625           Camara, Jacob                   1           camara, jacob
# 626           Sylla, Bakary                   1           sylla, bakary
# 627  Agafonov, Alexander P.                   1  agafonov, alexander p.
# 628        Grant, Alison D.                   1        grant, alison d.
#
#      Unnamed: 0   0     firstname ga_first_name ga_gender  ga_accuracy  \
# 0             2  44         Heinz         Heinz      male         98.0
# 1            80   8     Daniel G.     Daniel G.      male        100.0
# 2             3  33     Stuart T.        Stuart      male         99.0
# 3             4  32       Stephan       Stephan      male         99.0
# 4             1  47     Thomas W.     Thomas W.      male        100.0
# ..          ...  ..           ...           ...       ...          ...
# 624        4033   1       Oleg V.       Oleg V.      male        100.0
# 625         903   2         Jacob         Jacob      male         99.0
# 626        4045   1        Bakary        Bakary      male         99.0
# 627        4047   1  Alexander P.  Alexander P.      male        100.0
# 628        1887   1     Alison D.     Alison D.    female        100.0
#
#      ga_samples Unnamed: 8
# 0        3977.0          0
# 1          24.0          0
# 2       12253.0          0
# 3       19941.0          0
# 4          24.0          0
# ..          ...        ...
# 624         6.0          0
# 625     25605.0          0
# 626      1775.0          0
# 627         4.0          0
# 628         2.0          0
#
# [629 rows x 11 columns]

# %%
no_fund_author_full_names_list_count_2007_concat['ga_gender'].value_counts()
# Out:
# male            393
# female          204
# unclassified     31
# unknown           1
# Name: ga_gender, dtype: int64

# %%
no_fund_author_full_names_list_count_2007_concat['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.624801
# female          0.324324
# unclassified    0.049285
# unknown         0.001590
# Name: ga_gender, dtype: float64

# %%
# no_fund_data_author_lower_dummies = data_author_lower_dummies.reset_index().loc[data_author_lower_dummies.reset_index()['funding_yes'] == 0]
# no_fund_data_author_lower_dummies.shape

# %%
# no_fund_year_gender = no_fund_data_author_lower_dummies.reset_index()[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']
#                                                      ].groupby(['Publication Year']).agg({'female': 'sum', 'male': 'sum',
#                                                                                           'unclassified': 'sum', 'unknown': 'sum', 'number_of_author': 'sum',
#                                                                                           'UT (Unique WOS ID)': 'count'})

# no_fund_year_gender['female_to_male_ratio'] = no_fund_year_gender['female']/no_fund_year_gender['male']
# no_fund_year_gender['publication_to_authors_number_ratio'] = no_fund_year_gender['number_of_author']/no_fund_year_gender['UT (Unique WOS ID)']

# for col in ['female','male','unclassified','unknown']:
#     no_fund_year_gender['%_'+col] = no_fund_year_gender[col]/no_fund_year_gender['number_of_author']*100

# # #save data
# no_fund_year_gender.to_csv(f'../TABLES/year_gender_no_fund_count.csv')
# no_fund_year_gender

# %%
# no_fund_year_gender = no_fund_data_author_lower_dummies[['UT (Unique WOS ID)','Publication Year','female','male','unclassified','unknown','number_of_author']].groupby(['Publication Year']).sum()#.drop('funding_yes',axis=1)
# no_fund_year_gender['female_to_male_ratio'] = no_fund_year_gender['female']/no_fund_year_gender['male']

# for col in ['female','male','unclassified','unknown']:
#     no_fund_year_gender['%_'+col] = no_fund_year_gender[col]/no_fund_year_gender['number_of_author']*100

# # #save data
# no_fund_year_gender.to_csv(f'../DATA_PREPROCESSING/year_gender_no_fund_count.csv')
# no_fund_year_gender

# %% [markdown]
# ## significance

# %%
### compraring the female proportion

# %%
# limit data to after 2007
all_author_lower_dummies_2007 = data_author_lower_dummies.reset_index()[data_author_lower_dummies.reset_index()['Publication Year'] > 2006]
all_author_lower_dummies_2007.head()
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 0    WOS:000904661800001            2023.0
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 4    WOS:000849602200001            2022.0
# ..                   ...               ...
# 714  WOS:000244948100002            2007.0
# 715  WOS:000243871100009            2007.0
# 716  WOS:000244234800016            2007.0
# 717  WOS:000243692500011            2007.0
# 718  WOS:000243562000002            2007.0
#
#                                           Funding Orgs  funding_yes  female  \
# 0                                                  NaN            0     2.0
# 1    National Institutes of Health (NIH) [U19AI1427...            1     2.0
# 2           Russian Science Foundation;  [22-13-00036]            1     0.0
# 3    National Research Foundation of Korea (NRF) - ...            1     1.0
# 4                                                  NaN            0     0.0
# ..                                                 ...          ...     ...
# 714                                                NaN            0     0.0
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1     4.0
# 716                                                NaN            0     0.0
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1     3.0
# 718                                                NaN            0     4.0
#
#      male  unclassified  unknown  number_of_author   %_female      %_male  \
# 0     7.0           3.0      1.0              13.0  15.384615   53.846154
# 1     9.0           0.0      0.0              11.0  18.181818   81.818182
# 2     1.0           0.0      0.0               1.0   0.000000  100.000000
# 3    12.0           1.0      0.0              14.0   7.142857   85.714286
# 4     6.0           0.0      0.0               6.0   0.000000  100.000000
# ..    ...           ...      ...               ...        ...         ...
# 714   2.0           0.0      0.0               2.0   0.000000  100.000000
# 715   2.0           0.0      1.0               7.0  57.142857   28.571429
# 716   2.0           0.0      0.0               2.0   0.000000  100.000000
# 717  21.0           0.0      0.0              24.0  12.500000   87.500000
# 718   4.0           0.0      0.0               8.0  50.000000   50.000000
#
#      %_unclass_name  female_to_male_ratio
# 0         23.076923              0.285714
# 1          0.000000              0.222222
# 2          0.000000              0.000000
# 3          7.142857              0.083333
# 4          0.000000              0.000000
# ..              ...                   ...
# 714        0.000000              0.000000
# 715        0.000000              2.000000
# 716        0.000000              0.000000
# 717        0.000000              0.142857
# 718        0.000000              1.000000
#
# [714 rows x 13 columns]

# %%
fund_all_author_gender_2007 = all_author_lower_dummies_2007.loc[all_author_lower_dummies_2007['funding_yes'] == 1]
no_fund_all_author_gender_2007 = all_author_lower_dummies_2007.loc[all_author_lower_dummies_2007['funding_yes'] == 0]

# %%
all_author_lower_dummies_2007['%_female'].describe()
# Out:
# count    714.000000
# mean      33.503799
# std       24.045653
# min        0.000000
# 25%       16.666667
# 50%       33.333333
# 75%       50.000000
# max      100.000000
# Name: %_female, dtype: float64

# %%
fund_all_author_gender_2007['%_female'].describe()
# Out:
# count    563.000000
# mean      34.419170
# std       22.323173
# min        0.000000
# 25%       20.000000
# 50%       33.333333
# 75%       50.000000
# max      100.000000
# Name: %_female, dtype: float64

# %%
no_fund_all_author_gender_2007['%_female'].describe()
# Out:
# count    151.000000
# mean      30.090860
# std       29.435033
# min        0.000000
# 25%        0.000000
# 50%       27.777778
# 75%       50.000000
# max      100.000000
# Name: %_female, dtype: float64

# %%
test_sig(fund_all_author_gender_2007['%_female'], no_fund_all_author_gender_2007['%_female'])
# Out:
# mann-whitney
# MannwhitneyuResult(statistic=47969.0, pvalue=0.014832120105879979)

# %% [markdown]
# # first authors gender

# %%
first_author_gender = data_author_lower[0].to_frame().rename(columns={0:'ga_gender'})
#save data
first_author_gender.to_csv(f'../DATA_PREPROCESSING/first_author_gender.csv')
first_author_gender
# Out:
#                                                                                                         ga_gender
# UT (Unique WOS ID)  Publication Year Funding Orgs                                       funding_yes
# WOS:000904661800001 2023.0           NaN                                                0                    male
# WOS:000921279800001 2023.0           National Institutes of Health (NIH) [U19AI14278... 1                    male
# WOS:000909001200001 2023.0           Russian Science Foundation;  [22-13-00036]         1                    male
# WOS:000777045900001 2022.0           National Research Foundation of Korea (NRF) - M... 1                    male
# WOS:000849602200001 2022.0           NaN                                                0                    male
# ...                                                                                                           ...
# WOS:A1968B358900049 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300001 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300006 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300008 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300007 1968.0           NaN                                                0            unclassified
#
# [932 rows x 1 columns]

# %%
# limit data to after 2007
first_author_gender_2007 = first_author_gender.reset_index()[first_author_gender.reset_index()['Publication Year'] > 2006]
first_author_gender_2007#.head()
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 0    WOS:000904661800001            2023.0
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 4    WOS:000849602200001            2022.0
# ..                   ...               ...
# 714  WOS:000244948100002            2007.0
# 715  WOS:000243871100009            2007.0
# 716  WOS:000244234800016            2007.0
# 717  WOS:000243692500011            2007.0
# 718  WOS:000243562000002            2007.0
#
#                                           Funding Orgs  funding_yes ga_gender
# 0                                                  NaN            0      male
# 1    National Institutes of Health (NIH) [U19AI1427...            1      male
# 2           Russian Science Foundation;  [22-13-00036]            1      male
# 3    National Research Foundation of Korea (NRF) - ...            1      male
# 4                                                  NaN            0      male
# ..                                                 ...          ...       ...
# 714                                                NaN            0      male
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1      male
# 716                                                NaN            0      male
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1      male
# 718                                                NaN            0      male
#
# [714 rows x 5 columns]

# %%
first_author_gender_2007['ga_gender'].value_counts()
# Out:
# male            406
# female          287
# unclassified     19
# unknown           2
# Name: ga_gender, dtype: int64

# %%
first_author_gender_2007['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.568627
# female          0.401961
# unclassified    0.026611
# unknown         0.002801
# Name: ga_gender, dtype: float64

# %% [markdown]
# ## funding

# %%
fund_first_author_gender_2007 = first_author_gender_2007.loc[first_author_gender_2007['funding_yes'] == 1]

# %%
fund_first_author_gender_2007['ga_gender'].value_counts()
# Out:
# male            305
# female          243
# unclassified     13
# unknown           2
# Name: ga_gender, dtype: int64

# %%
fund_first_author_gender_2007['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.541741
# female          0.431616
# unclassified    0.023091
# unknown         0.003552
# Name: ga_gender, dtype: float64

# %%
fund_first_author_gender_2007.shape
# Out:
# (563, 5)

# %% [markdown]
# ## no funding

# %%
no_fund_first_author_gender_2007 = first_author_gender_2007.loc[first_author_gender_2007['funding_yes'] == 0]

# %%
no_fund_first_author_gender_2007['ga_gender'].value_counts()
# Out:
# male            101
# female           44
# unclassified      6
# Name: ga_gender, dtype: int64

# %%
no_fund_first_author_gender_2007['ga_gender'].value_counts(normalize=True)
# Out:
# male            0.668874
# female          0.291391
# unclassified    0.039735
# Name: ga_gender, dtype: float64

# %%
no_fund_first_author_gender_2007.shape
# Out:
# (151, 5)

# %% [markdown]
# ## significance

# %%
fund_first_author_gender_2007[fund_first_author_gender_2007['ga_gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 6    WOS:000905136600002            2022.0
# 10   WOS:000896010800003            2022.0
# ..                   ...               ...
# 708  WOS:000244881900014            2007.0
# 709  WOS:000244881900012            2007.0
# 712  WOS:000249426800015            2007.0
# 715  WOS:000243871100009            2007.0
# 717  WOS:000243692500011            2007.0
#
#                                           Funding Orgs  funding_yes  ga_gender
# 1    National Institutes of Health (NIH) [U19AI1427...            1          1
# 2           Russian Science Foundation;  [22-13-00036]            1          1
# 3    National Research Foundation of Korea (NRF) - ...            1          1
# 6    Intramural Research Program of the Vaccine Res...            1          0
# 10   National Institutes of Health [R33AI100190, AI...            1          0
# ..                                                 ...          ...        ...
# 708  NATIONAL INSTITUTE OF ALLERGY AND INFECTIOUS D...            1          0
# 709  NIDCD NIH HHS [R01 DC003299] Funding Source: M...            1          0
# 712  NIAID NIH HHS [R21 AI063436, R21 AI063436-01A1...            1          0
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1          1
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1          1
#
# [548 rows x 5 columns]

# %%
fund_first_author_gender_2007_test = fund_first_author_gender_2007[fund_first_author_gender_2007['ga_gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})['ga_gender']
no_fund_first_author_gender_2007_test = no_fund_first_author_gender_2007[no_fund_first_author_gender_2007['ga_gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})['ga_gender']

# %%
test_sig(fund_first_author_gender_2007_test, no_fund_first_author_gender_2007_test)
# Out:
# mann-whitney
# MannwhitneyuResult(statistic=34168.5, pvalue=0.002361160480953111)

# %%
fund_first_author_gender_2007_test.shape
# Out:
# (548, 5)

# %%
fund_first_author_gender_2007_test['ga_gender'].value_counts()
# Out:
# 1    305
# 0    243
# Name: ga_gender, dtype: int64

# %%
no_fund_first_author_gender_2007_test.shape
# Out:
# (145, 5)

# %%
no_fund_first_author_gender_2007_test['ga_gender'].value_counts()
# Out:
# 1    101
# 0     44
# Name: ga_gender, dtype: int64

# %% [markdown]
# # last authors gender

# %% [markdown]
# ## all

# %%
# create a columns of funding yes or no
data['funding_yes'] = data['Funding Orgs'].apply(lambda x: 1 if not pd.isnull(x) else 0)
# data = data.loc[data.reset_index()['funding_yes'] == 0]

data = data.set_index(['UT (Unique WOS ID)','Publication Year','Funding Orgs','funding_yes'])
last_author_gender = data['Author Full Names'].map(lambda x: x.split('; ')[-1]).str.lower().to_frame()
last_author_gender['gender'] = last_author_gender['Author Full Names'].map(name_gender_keys_values)

#save data
last_author_gender.to_csv(f'../DATA_PREPROCESSING/last_author_gender.csv')
last_author_gender
# Out:
#                                                                                                              Author Full Names  \
# UT (Unique WOS ID)  Publication Year Funding Orgs                                       funding_yes
# WOS:000904661800001 2023.0           NaN                                                0                         xia, xianzhu
# WOS:000921279800001 2023.0           National Institutes of Health (NIH) [U19AI14278... 1                         heyes, james
# WOS:000909001200001 2023.0           Russian Science Foundation;  [22-13-00036]         1                moskalik, mikhail yu.
# WOS:000777045900001 2022.0           National Research Foundation of Korea (NRF) - M... 1            hassan, mohammad mahmudul
# WOS:000849602200001 2022.0           NaN                                                0                       dhama, kuldeep
# ...                                                                                                                        ...
# WOS:A1968B358900049 1968.0           NaN                                                0                           strickla.m
# WOS:A1968A855300001 1968.0           NaN                                                0                           baltzer, g
# WOS:A1968A855300006 1968.0           NaN                                                0                          slenczka, w
# WOS:A1968A855300008 1968.0           NaN                                                0                          slenczka, w
# WOS:A1968A855300007 1968.0           NaN                                                0                           siegert, r
#
#                                                                                                            gender
# UT (Unique WOS ID)  Publication Year Funding Orgs                                       funding_yes
# WOS:000904661800001 2023.0           NaN                                                0                  female
# WOS:000921279800001 2023.0           National Institutes of Health (NIH) [U19AI14278... 1                    male
# WOS:000909001200001 2023.0           Russian Science Foundation;  [22-13-00036]         1                    male
# WOS:000777045900001 2022.0           National Research Foundation of Korea (NRF) - M... 1                    male
# WOS:000849602200001 2022.0           NaN                                                0                    male
# ...                                                                                                           ...
# WOS:A1968B358900049 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300001 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300006 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300008 1968.0           NaN                                                0            unclassified
# WOS:A1968A855300007 1968.0           NaN                                                0            unclassified
#
# [932 rows x 2 columns]

# %%
# limit data to after 2007
last_author_gender_2007 = last_author_gender.reset_index()
last_author_gender_2007 = last_author_gender_2007[last_author_gender_2007['Publication Year'] > 2006]
last_author_gender_2007#.head()
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 0    WOS:000904661800001            2023.0
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 4    WOS:000849602200001            2022.0
# ..                   ...               ...
# 714  WOS:000244948100002            2007.0
# 715  WOS:000243871100009            2007.0
# 716  WOS:000244234800016            2007.0
# 717  WOS:000243692500011            2007.0
# 718  WOS:000243562000002            2007.0
#
#                                           Funding Orgs  funding_yes  \
# 0                                                  NaN            0
# 1    National Institutes of Health (NIH) [U19AI1427...            1
# 2           Russian Science Foundation;  [22-13-00036]            1
# 3    National Research Foundation of Korea (NRF) - ...            1
# 4                                                  NaN            0
# ..                                                 ...          ...
# 714                                                NaN            0
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1
# 716                                                NaN            0
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1
# 718                                                NaN            0
#
#              Author Full Names  gender
# 0                 xia, xianzhu  female
# 1                 heyes, james    male
# 2        moskalik, mikhail yu.    male
# 3    hassan, mohammad mahmudul    male
# 4               dhama, kuldeep    male
# ..                         ...     ...
# 714      mohamadzadeh, mansour    male
# 715                rong, lijun  female
# 716        geisbert, thomas w.    male
# 717             lipkin, w. ian    male
# 718           grant, alison d.  female
#
# [714 rows x 6 columns]

# %%
last_author_gender_2007['gender'].value_counts()
# Out:
# male            562
# female          138
# unclassified     12
# unknown           2
# Name: gender, dtype: int64

# %%
last_author_gender_2007['gender'].value_counts(normalize=True)
# Out:
# male            0.787115
# female          0.193277
# unclassified    0.016807
# unknown         0.002801
# Name: gender, dtype: float64

# %% [markdown]
# ## funding

# %%
fund_last_author_gender_2007 = last_author_gender_2007.loc[last_author_gender_2007['funding_yes'] == 1]

# %%
fund_last_author_gender_2007['gender'].value_counts()
# Out:
# male            446
# female          109
# unclassified      6
# unknown           2
# Name: gender, dtype: int64

# %%
fund_last_author_gender_2007['gender'].value_counts(normalize=True)
# Out:
# male            0.792185
# female          0.193606
# unclassified    0.010657
# unknown         0.003552
# Name: gender, dtype: float64

# %%
fund_last_author_gender_2007.shape
# Out:
# (563, 6)

# %% [markdown]
# ## no funding

# %%
no_fund_last_author_gender_2007 = last_author_gender_2007.loc[last_author_gender_2007['funding_yes'] == 0]

# %%
no_fund_last_author_gender_2007['gender'].value_counts()
# Out:
# male            116
# female           29
# unclassified      6
# Name: gender, dtype: int64

# %%
no_fund_last_author_gender_2007['gender'].value_counts(normalize=True)
# Out:
# male            0.768212
# female          0.192053
# unclassified    0.039735
# Name: gender, dtype: float64

# %%
no_fund_last_author_gender_2007.shape
# Out:
# (151, 6)

# %%
last_author_gender_2007
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 0    WOS:000904661800001            2023.0
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 4    WOS:000849602200001            2022.0
# ..                   ...               ...
# 714  WOS:000244948100002            2007.0
# 715  WOS:000243871100009            2007.0
# 716  WOS:000244234800016            2007.0
# 717  WOS:000243692500011            2007.0
# 718  WOS:000243562000002            2007.0
#
#                                           Funding Orgs  funding_yes  \
# 0                                                  NaN            0
# 1    National Institutes of Health (NIH) [U19AI1427...            1
# 2           Russian Science Foundation;  [22-13-00036]            1
# 3    National Research Foundation of Korea (NRF) - ...            1
# 4                                                  NaN            0
# ..                                                 ...          ...
# 714                                                NaN            0
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1
# 716                                                NaN            0
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1
# 718                                                NaN            0
#
#              Author Full Names  gender
# 0                 xia, xianzhu  female
# 1                 heyes, james    male
# 2        moskalik, mikhail yu.    male
# 3    hassan, mohammad mahmudul    male
# 4               dhama, kuldeep    male
# ..                         ...     ...
# 714      mohamadzadeh, mansour    male
# 715                rong, lijun  female
# 716        geisbert, thomas w.    male
# 717             lipkin, w. ian    male
# 718           grant, alison d.  female
#
# [714 rows x 6 columns]

# %% [markdown]
# ## significance

# %%
fund_last_author_gender_2007[fund_last_author_gender_2007['gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})
# Out:
#       UT (Unique WOS ID)  Publication Year  \
# 1    WOS:000921279800001            2023.0
# 2    WOS:000909001200001            2023.0
# 3    WOS:000777045900001            2022.0
# 6    WOS:000905136600002            2022.0
# 10   WOS:000896010800003            2022.0
# ..                   ...               ...
# 708  WOS:000244881900014            2007.0
# 709  WOS:000244881900012            2007.0
# 712  WOS:000249426800015            2007.0
# 715  WOS:000243871100009            2007.0
# 717  WOS:000243692500011            2007.0
#
#                                           Funding Orgs  funding_yes  \
# 1    National Institutes of Health (NIH) [U19AI1427...            1
# 2           Russian Science Foundation;  [22-13-00036]            1
# 3    National Research Foundation of Korea (NRF) - ...            1
# 6    Intramural Research Program of the Vaccine Res...            1
# 10   National Institutes of Health [R33AI100190, AI...            1
# ..                                                 ...          ...
# 708  NATIONAL INSTITUTE OF ALLERGY AND INFECTIOUS D...            1
# 709  NIDCD NIH HHS [R01 DC003299] Funding Source: M...            1
# 712  NIAID NIH HHS [R21 AI063436, R21 AI063436-01A1...            1
# 715  NCI NIH HHS [CA 092459] Funding Source: Medlin...            1
# 717  NIAID NIH HHS [R01 AI051292, R21 AI056118, AI0...            1
#
#              Author Full Names  gender
# 1                 heyes, james       1
# 2        moskalik, mikhail yu.       1
# 3    hassan, mohammad mahmudul       1
# 6           sullivan, nancy j.       0
# 10                 gehrke, lee       1
# ..                         ...     ...
# 708               bavari, sina       1
# 709            becker, stephan       1
# 712          muehlberger, elke       0
# 715                rong, lijun       0
# 717             lipkin, w. ian       1
#
# [555 rows x 6 columns]

# %%
fund_last_author_gender_2007_test = fund_last_author_gender_2007[fund_last_author_gender_2007['gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})['gender']
no_fund_last_author_gender_2007_test = no_fund_last_author_gender_2007[no_fund_last_author_gender_2007['gender'].isin(['male', 'female'])].replace({'male': 1, 'female': 0})['gender']

# %%
test_sig(fund_last_author_gender_2007_test, no_fund_last_author_gender_2007_test)
# Out:
# mann-whitney
# MannwhitneyuResult(statistic=40382.5, pvalue=0.9229519490866986)

# %% [markdown]
# # significance

# %%
# limit data to after 2007
data_author_lower_dummies_2007 = data_author_lower_dummies.reset_index()[data_author_lower_dummies.reset_index()['Publication Year'] > 2006]
data_author_lower_dummies_2007.head()
# Out:
#     UT (Unique WOS ID)  Publication Year  \
# 0  WOS:000904661800001            2023.0
# 1  WOS:000921279800001            2023.0
# 2  WOS:000909001200001            2023.0
# 3  WOS:000777045900001            2022.0
# 4  WOS:000849602200001            2022.0
#
#                                         Funding Orgs  funding_yes  female  \
# 0                                                NaN            0     2.0
# 1  National Institutes of Health (NIH) [U19AI1427...            1     2.0
# 2         Russian Science Foundation;  [22-13-00036]            1     0.0
# 3  National Research Foundation of Korea (NRF) - ...            1     1.0
# 4                                                NaN            0     0.0
#
#    male  unclassified  unknown  number_of_author   %_female      %_male  \
# 0   7.0           3.0      1.0              13.0  15.384615   53.846154
# 1   9.0           0.0      0.0              11.0  18.181818   81.818182
# 2   1.0           0.0      0.0               1.0   0.000000  100.000000
# 3  12.0           1.0      0.0              14.0   7.142857   85.714286
# 4   6.0           0.0      0.0               6.0   0.000000  100.000000
#
#    %_unclass_name  female_to_male_ratio
# 0       23.076923              0.285714
# 1        0.000000              0.222222
# 2        0.000000              0.000000
# 3        7.142857              0.083333
# 4        0.000000              0.000000

# %%
data_author_lower_dummies_2007.describe()
# Out:
#        Publication Year  funding_yes      female        male  unclassified  \
# count        714.000000   714.000000  714.000000  714.000000    714.000000
# mean        2015.537815     0.788515    2.810924    5.207283      0.218487
# std            4.403473     0.408647    2.590162    4.698381      1.025561
# min         2007.000000     0.000000    0.000000    0.000000      0.000000
# 25%         2012.000000     1.000000    1.000000    2.000000      0.000000
# 50%         2016.000000     1.000000    2.000000    4.000000      0.000000
# 75%         2019.000000     1.000000    4.000000    7.000000      0.000000
# max         2023.000000     1.000000   18.000000   58.000000     17.000000
#
#           unknown  number_of_author    %_female      %_male  %_unclass_name  \
# count  714.000000        714.000000  714.000000  714.000000      714.000000
# mean     0.030812          8.267507   33.503799   63.371826        2.791472
# std      0.188454          6.549617   24.045653   24.798693       12.591060
# min      0.000000          1.000000    0.000000    0.000000        0.000000
# 25%      0.000000          4.000000   16.666667   50.000000        0.000000
# 50%      0.000000          7.000000   33.333333   63.636364        0.000000
# 75%      0.000000         11.000000   50.000000   80.000000        0.000000
# max      2.000000         76.000000  100.000000  100.000000      100.000000
#
#        female_to_male_ratio
# count            706.000000
# mean                    inf
# std                     NaN
# min                0.000000
# 25%                0.205556
# 50%                0.500000
# 75%                1.000000
# max                     inf

# %%
data_author_lower_dummies_2007['female_to_male_ratio'].value_counts().to_frame()
# Out:
#           female_to_male_ratio
# 0.000000                   119
# 1.000000                    83
# 0.500000                    47
# 0.333333                    35
# 0.666667                    28
# ...                        ...
# 0.307692                     1
# 1.600000                     1
# 0.230769                     1
# 0.277778                     1
# 0.416667                     1
#
# [89 rows x 1 columns]

# %%
data_author_lower_dummies['female_to_male_ratio'].count()
# Out:
# 853

# %%
data_author_lower_dummies_2007['female_to_male_ratio'].value_counts().to_frame()['female_to_male_ratio'].sum()
# Out:
# 706

# %%
data_author_lower_dummies_2007.loc[data_author_lower_dummies_2007['funding_yes'] == 0].describe()
# Out:
#        Publication Year  funding_yes      female        male  unclassified  \
# count        151.000000        151.0  151.000000  151.000000    151.000000
# mean        2013.556291          0.0    1.516556    3.344371      0.211921
# std            5.142808          0.0    1.656721    2.754503      0.744842
# min         2007.000000          0.0    0.000000    0.000000      0.000000
# 25%         2009.000000          0.0    0.000000    1.000000      0.000000
# 50%         2013.000000          0.0    1.000000    2.000000      0.000000
# 75%         2018.000000          0.0    2.000000    5.000000      0.000000
# max         2023.000000          0.0    9.000000   14.000000      6.000000
#
#           unknown  number_of_author    %_female      %_male  %_unclass_name  \
# count  151.000000        151.000000  151.000000  151.000000      151.000000
# mean     0.006623          5.079470   30.090860   65.573369        4.284828
# std      0.081379          3.539347   29.435033   30.446068       16.543160
# min      0.000000          1.000000    0.000000    0.000000        0.000000
# 25%      0.000000          2.000000    0.000000   50.000000        0.000000
# 50%      0.000000          4.000000   27.777778   66.666667        0.000000
# 75%      0.000000          7.000000   50.000000  100.000000        0.000000
# max      1.000000         19.000000  100.000000  100.000000      100.000000
#
#        female_to_male_ratio
# count            148.000000
# mean                    inf
# std                     NaN
# min                0.000000
# 25%                0.000000
# 50%                0.464286
# 75%                1.000000
# max                     inf

# %%
data_author_lower_dummies_2007.loc[data_author_lower_dummies_2007['funding_yes'] == 1].describe()
# Out:
#        Publication Year  funding_yes      female        male  unclassified  \
# count        563.000000        563.0  563.000000  563.000000    563.000000
# mean        2016.069272          1.0    3.158082    5.706927      0.220249
# std            4.025342          0.0    2.684783    4.979789      1.089165
# min         2007.000000          1.0    0.000000    0.000000      0.000000
# 25%         2013.000000          1.0    1.000000    3.000000      0.000000
# 50%         2017.000000          1.0    3.000000    5.000000      0.000000
# 75%         2019.000000          1.0    5.000000    7.000000      0.000000
# max         2023.000000          1.0   18.000000   58.000000     17.000000
#
#           unknown  number_of_author    %_female      %_male  %_unclass_name  \
# count  563.000000        563.000000  563.000000  563.000000      563.000000
# mean     0.037300          9.122558   34.419170   62.781359        2.390945
# std      0.207582          6.900480   22.323173   23.046629       11.283851
# min      0.000000          1.000000    0.000000    0.000000        0.000000
# 25%      0.000000          5.000000   20.000000   50.000000        0.000000
# 50%      0.000000          8.000000   33.333333   63.636364        0.000000
# 75%      0.000000         12.000000   50.000000   77.777778        0.000000
# max      2.000000         76.000000  100.000000  100.000000      100.000000
#
#        female_to_male_ratio
# count                558.00
# mean                    inf
# std                     NaN
# min                    0.00
# 25%                    0.25
# 50%                    0.50
# 75%                    1.00
# max                     inf

# %%
# data_author_lower_dummies_2007

# %%
# data_author_lower['number_of_author'] = data_author_lower.count(axis='columns')
# data_author_lower['number_of_male'] = (data_author_lower == 'male').sum(axis=1)
# data_author_lower['number_of_female'] = (data_author_lower == 'female').sum(axis=1)
# data_author_lower['number_of_unknown_or_unclassified'] = ((data_author_lower == '/') | (data_author_lower == 'unknown')).sum(axis=1)
# data_author_lower['proportion_unclass_name'] = data_author_lower['number_of_unknown_or_unclassified']/data_author_lower['number_of_author']*100
# data_author_lower['female_to_male_ratio'] = data_author_lower['number_of_female']/data_author_lower['number_of_male']
# data_author_lower['first_author_gender'] = data_author_lower[0]
# # data_author_lower['first_author_gender'] =

# #save data
# data_author_lower.to_csv(f'../DATA_PREPROCESSING/author_gender_list_count.csv')
# data_author_lower

# %%
# data_author_lower['female_to_male_ratio'].count()
